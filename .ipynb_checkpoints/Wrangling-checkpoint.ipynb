# %%
import json
import numpy as np
import urllib
import os
import urllib.request
import pandas as pd
import re

# %%
# os.chdir("TourismBali")
# os.getcwd()

# %%
file_labels = open('google_vision_label.json').read()
file_data = open('treated_bali_data.json').read()
perfect_key = pd.read_csv('df_bali_data.csv', encoding = 'latin-1')

# %%
dict_labels = json.loads(file_labels)
dict_data = json.loads(file_data)

# %%
print(len(dict_labels))
print(len(dict_data))
# Out:
# 12363
# 41322

# %%
perfect_key['real_key'] =  perfect_key['URL'].apply(lambda x: re.sub(r'https://live.staticflickr.com/.+/','', str(x)))
perfect_key['real_key'] =  perfect_key['real_key'].apply(lambda x: re.sub(r'_.+','', str(x)))

# %% [markdown]
# # Reverse Label With Dict - SOLVED

# %%
label_support_dict = dict()

# %%
for i in range(len(perfect_key)):
    try:
        label_support_dict[str(perfect_key.iloc[i, 10])] = dict_labels[str(perfect_key.iloc[i, 0])]
    except:
        pass

# %%
print(len(label_support_dict))
# Out:
# 12352

# %%
with open('google_vision_label.json', 'w') as json_file:
    json.dump(label_support_dict, json_file)

# %% [markdown]
# # Search LABELS

# %%
key_dict = pd.Series(perfect_key.real_key.values,index=perfect_key.ID).to_dict()

# %%
data_support_dict = dict()

# %%
a = 0

# %%
for key in dict_data.keys():
    
    try:
        dict_data[key]['label'] = label_support_dict[key]
        data_support_dict[key] = dict_data[key]
        a +=1
    except:
        pass

# %%
final_dict_data = dict()

# %%
for element in data_support_dict.keys():
    
    final_dict_data[element] = dict()
    final_dict_data[element]['url'] = data_support_dict[element]['url'] 
    final_dict_data[element]['latitude'] = data_support_dict[element]['latitude'] 
    final_dict_data[element]['county'] = data_support_dict[element]['county'] 
    final_dict_data[element]['longitude'] = data_support_dict[element]['longitude'] 
    final_dict_data[element]['tags'] = data_support_dict[element]['tags']    
    final_dict_data[element]['label'] = data_support_dict[element]['label']

# %%
for element in final_dict_data.keys():
    
    tags = final_dict_data[element]['tags']
    tags =  [x for x in tags if not bool(re.search('four', x))]
    tags =  [x for x in tags if not bool(re.search('bali', x))]
    tags =  [x for x in tags if not bool(re.search('indon', x))]
    tags =  [x for x in tags if not bool(re.search('instagram', x))]
    tags =  [x for x in tags if not bool(re.search('iphone', x))]
    tags =  [x for x in tags if not bool(re.search('square', x))]
    
    final_dict_data[element]['tags'] = tags

# %%
with open('data_bali.json', 'w') as json_file:
    json.dump(final_dict_data, json_file)

# %% [markdown]
# # Search URL

# %%
a = 0
url_list = list(perfect_key['URL'])

# %%
for element in final_dict_data.keys():
    
    try:
        url = [x for x in url_list if re.search(element, x)][0]
        final_dict_data[element]['url'] = url
        a+=1
    except:
        pass

# %%
final_dict_data['25291754827']
# Out:
# {'url': 'https://live.staticflickr.com/4670/25291754827_22b6fde8d3.jpg',
#  'latitude': '-8.775537',
#  'county': 'Badung Kabupaten',
#  'longitude': '115.166861',
#  'tags': [''],
#  'label': ['Sky',
#   'Body of water',
#   'Water',
#   'Blue',
#   'Nature',
#   'Sea',
#   'Cloud',
#   'Ocean',
#   'Water resources',
#   'Coast']}

# %% [markdown]
# # Donwload Images

# %%
os.chdir("www")

# %%
file_list = os.listdir()

# %%
for file in file_list:
    
    if bool(re.search(".jpg", file)):
        
        shutil.move(file, str('www/' + file))
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  
#  '19613581336.jpg',
#  '19622797192.jpg',
#  '19628209144.jpg',
#  '19628675225.jpg',
#  '19637583653.jpg',
#  '19639767535.jpg',
#  '19640952204.jpg',
#  '19644202801.jpg',
#  '19644205041.jpg',
#  '19644206501.jpg',
#  '19668779478.jpg',
#  '19670657579.jpg',
#  '19670716838.jpg',
#  '19671009218.jpg',
#  '19671017758.jpg',
#  '19671026198.jpg',
#  '19671030740.jpg',
#  '19671042990.jpg',
#  '19671049190.jpg',
#  '19671050670.jpg',
#  '19671053410.jpg',
#  '19671499718.jpg',
#  '19671504338.jpg',
#  '19671509698.jpg',
#  '19671535070.jpg',
#  '19671567618.jpg',
#  '19671569888.jpg',
#  '19671593980.jpg',
#  '19672458719.jpg',
#  '19672463299.jpg',
#  '19672476629.jpg',
#  '19672958899.jpg',
#  '19672966409.jpg',
#  '19673018309.jpg',
#  '19677111710.jpg',
#  '19677154658.jpg',
#  '19677702350.jpg',
#  '19677714208.jpg',
#  '19677774000.jpg',
#  '19677787578.jpg',
#  '19677855030.jpg',
#  '19679026429.jpg',
#  '19679150939.jpg',
#  '19679184719.jpg',
#  '19683153358.jpg',
#  '19687205818.jpg',
#  '19688329498.jpg',
#  '19689363920.jpg',
#  '19689749858.jpg',
#  '19690421200.jpg',
#  '19690562590.jpg',
#  '19690570870.jpg',
#  '19690895271.jpg',
#  '19701905132.jpg',
#  '19705495745.jpg',
#  '19708832874.jpg',
#  ...]

# %%
a = 0
for element in final_dict_data.keys():
    try:
        urllib.request.urlretrieve(final_dict_data[element]['url'], str(element+ '.jpg'))
        a +=1
    except:
        pass

# %%
for i in range(len(perfect_key)):

# %%
    
    if element in list(perfect_key['url']):
        
        final_dict_data['element']['url'] =

# %%
15986256617

# %%
perfect_key['real_key']
# Out:
# 0        28292474313
# 1        28832277511
# 2        28395877424
# 3        28983249496
# 4        28910903782
#             ...
# 12359    39345542150
# 12360    44566319890
# 12361    35045067493
# 12362    38545322792
# 12363    44055140550
# Name: real_key, Length: 12364, dtype: object

# %%
print(list(filter(lambda x : re.search(r".{6}1234\s{3}SD",x) ,somelist)))

# %%
a
# Out:
# 0

# %%
for key in dict_data.keys():
    try:
        data_support_dict[key] = dict_data[key]
        data_support_dict[key]['label'] = dict_data[key_dict[key]]['label']
        data_support_dict[key]['url'] = dict_data[key_dict[key]]['url']
    except:
        pass

# %%
len(data_support_dict)
# Out:
# 41322

# %%
data_support_dict = dict()
label_support_dict = dict()

# %%
perfect_key['real_key'] =  perfect_key['URL'].apply(lambda x: re.sub(r'https://live.staticflickr.com/.+/','', str(x)))
perfect_key['real_key'] =  perfect_key['real_key'].apply(lambda x: re.sub(r'_.+','', str(x)))

# %%
for i in range(len(perfect_key)):
    try:
        data_support_dict[str(perfect_key.iloc[i, 10])] = dict_data[str(perfect_key.iloc[i, 0])]
        label_support_dict[str(perfect_key.iloc[i, 10])] = dict_labels[str(perfect_key.iloc[i, 0])]
    except:
        pass

# %%
dict_data = data_support_dict
dict_labels = label_support_dict

# %%
import os
file_list = os.listdir('www')
file_list = [x.replace('.jpg', '') for x in file_list]

# %%
new_dict_data = dict()
final_dict_data = dict()

# %%
for element in dict_data.keys():
    if element in dict_labels.keys():
            new_dict_data[element] = dict_data[element]
            new_dict_data[element]['label'] = dict_labels[element]

# %%
for element in new_dict_data.keys():
    
    final_dict_data[element] = dict()
    final_dict_data[element]['url'] = new_dict_data[element]['url'] 
    final_dict_data[element]['latitude'] = new_dict_data[element]['latitude'] 
    final_dict_data[element]['county'] = new_dict_data[element]['county'] 
    final_dict_data[element]['longitude'] = new_dict_data[element]['longitude'] 
    final_dict_data[element]['tags'] = new_dict_data[element]['tags']    
    final_dict_data[element]['label'] = new_dict_data[element]['label']

# %%
for element in final_dict_data.keys():
    
    tags = final_dict_data[element]['tags']
    tags =  [x for x in tags if not bool(re.search('four', x))]
    tags =  [x for x in tags if not bool(re.search('bali', x))]
    tags =  [x for x in tags if not bool(re.search('indon', x))]
    tags =  [x for x in tags if not bool(re.search('instagram', x))]
    tags =  [x for x in tags if not bool(re.search('iphone', x))]
    tags =  [x for x in tags if not bool(re.search('square', x))]
    

    final_dict_data[element]['tags'] = tags

# %%
with open('data_bali.json', 'w') as json_file:
    json.dump(final_dict_data, json_file)

# %% [markdown]
# # Change Filenames

# %%
import os
file_list = os.listdir()
file_list = [x.replace('.jpg', '') for x in file_list]

# %%
key_dict = pd.Series(perfect_key.ID.values,index=perfect_key.real_key).to_dict()

# %%
# os.getcwd()
# os.chdir("www")

# %%
a = 0

# %%
for file in file_list:
    try:
        os.rename(file , str(key_dict[file] + '.jpg'))
        a +=1
    except:
        pass

# %%
a
# Out:
# 0

# %%
file_list
# Out:
# ['13861281725',
#  '13861290183',
#  '15546314293',
#  '15547119394',
#  '15550188123',
#  '15562129434',
#  '15567935804',
#  '15569423754',
#  '15581971744',
#  '15581980574',
#  '15581992784',
#  '15581995504',
#  '15582001714',
#  '15582002644',
#  '15582012114',
#  '15582016234',
#  '15582021434',
#  '15582024384',
#  '15582026774',
#  '15584573853',
#  '15584578383',
#  '15584578823',
#  '15584580423',
#  '15584580823',
#  '15584582263',
#  '15584584443',
#  '15587889234',
#  '15590541133',
#  '15617459813',
#  '15629717974',
#  '15630417364',
#  '15630490904',
#  '15631541184',
#  '15633081833',
#  '15633710563',
#  '15636606303',
#  '15637752044',
#  '15638664914',
#  '15638715424',
#  '15639210504',
#  '15640345133',
#  '15651279013',
#  '15653299724',
#  '15653301684',
#  '15657234983',
#  '15662726754',
#  '15664121874',
#  '15665448163',
#  '15665456693',
#  '15665460473',
#  '15668796544',
#  '15671211003',
#  '15671502873',
#  '15676620184',
#  '15677062314',
#  '15677353474',
#  '15677383114',
#  '15677383934',
#  '15677384374',
#  '15677384954',
#  '15677386834',
#  '15677418374',
#  '15677418764',
#  '15677421734',
#  '15679226323',
#  '15679593833',
#  '15679594593',
#  '15679595123',
#  '15679878403',
#  '15679879153',
#  '15679879503',
#  '15679946093',
#  '15679953203',
#  '15694824284',
#  '15696640143',
#  '15701164943',
#  '15701490194',
#  '15701496374',
#  '15702673613',
#  '16404009677',
#  '16404015684',
#  '16404260664',
#  '16405002219',
#  '16406031373',
#  '16406040629',
#  '16406102486',
#  '16406858422',
#  '16406931796',
#  '16407143981',
#  '16407262836',
#  '16407989682',
#  '16408640325',
#  '16409122615',
#  '16409301842',
#  '16410569579',
#  '16411616762',
#  '16411707369',
#  '16413332421',
#  '16413552102',
#  '16414016667',
#  '16414655112',
#  '16415471662',
#  '16416120025',
#  '16417926064',
#  '16418772304',
#  '16419854804',
#  '16420547186',
#  '16420690973',
#  '16420693823',
#  '16420771536',
#  '16421759513',
#  '16421923403',
#  '16422506640',
#  '16422574060',
#  '16422601890',
#  '16422604870',
#  '16423777919',
#  '16423889184',
#  '16423892934',
#  '16424690080',
#  '16425234691',
#  '16425696481',
#  '16425880244',
#  '16427045665',
#  '16428864894',
#  '16429317763',
#  '16429411966',
#  '16430041503',
#  '16430182526',
#  '16430356951',
#  '16431209916',
#  '16431221806',
#  '16432020418',
#  '16432545022',
#  '16433305418',
#  '16433328828',
#  '16433457760',
#  '16434539199',
#  '16434714236',
#  '16434752856',
#  '16434753616',
#  '16434755816',
#  '16434784496',
#  '16436173406',
#  '16440385651',
#  ...]

# %% [markdown]
# # Check

# %%
label_list = []
id_list = []
url_list = []
support_final_dict_data = final_dict_data.copy()
x = 0

# %%
for element in final_dict_data.keys():
    url_list.append(support_final_dict_data[element]['url'])
    id_list.append(element)

# %%
import re

# %%
#url_list = [re.sub(r'https://live.staticflickr.com/.+/', '', i) for i in url_list]
#url_list = [re.sub(r'_.+', '', i) for i in url_list]

# %%
for element in final_dict_data.keys():
    for element2 in support_final_dict_data.keys():
        if element2 in final_dict_data[element]['url']:
            x+=1

# %%
x
# Out:
# 5194

# %%
a
# Out:
# 750

# %% [markdown]
# # Download Images

# %%
os.chdir("www")

# %%
len(final_dict_data.keys())
# Out:
# 12363

# %%
a = 0
for element in final_dict_data.keys():
    if element not in file_list:
        try:
            a = a+1
            urllib.request.urlretrieve(final_dict_data[element]['url'], str(element+ '.jpg'))
        except:
            pass

# %%
beach = dict()

# %%
for element in final_dict_data.keys():
    if 'Beach' in final_dict_data[element]['label']:
        if float(final_dict_data[element]['latitude']) > -8.5:
            beach[element] =  final_dict_data[element]

# %%
len(beach)
# Out:
# 243

# %%
beach
# Out:
# {'28395877424': {'url': 'https://live.staticflickr.com/7778/28395877424_9c4bcf2363.jpg',
#   'latitude': '-8.419775',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.303016',
#   'tags': [''],
#   'label': ['Beach',
#    'Body of water',
#    'Coast',
#    'Sea',
#    'Sky',
#    'Shore',
#    'Ocean',
#    'Coastal and oceanic landforms',
#    'Sand',
#    'Vacation']},
#  '28910903782': {'url': 'https://live.staticflickr.com/8337/28910903782_7bb3d15335.jpg',
#   'latitude': '-8.415678',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.315291',
#   'tags': [''],
#   'label': ['Beach',
#    'Vacation',
#    'Sea',
#    'Ocean',
#    'Coast',
#    'Sky',
#    'Shore',
#    'Tourism',
#    'Horizon',
#    'Resort']},
#  '28983249356': {'url': 'https://live.staticflickr.com/8467/28983249356_2dc33442d8.jpg',
#   'latitude': '-8.415512',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.315474',
#   'tags': [''],
#   'label': ['Fun',
#    'Vacation',
#    'Beach',
#    'Leisure',
#    'Sand',
#    'Village',
#    'Tourism']},
#  '28983249076': {'url': 'https://live.staticflickr.com/8448/28983249076_99273b94ac.jpg',
#   'latitude': '-8.414909',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.315850',
#   'tags': [''],
#   'label': ['Beach',
#    'People on beach',
#    'Sun tanning',
#    'Coast',
#    'Shore',
#    'Vacation',
#    'Sea',
#    'Tourism',
#    'Summer',
#    'Sand']},
#  '28910903592': {'url': 'https://live.staticflickr.com/8081/28910903592_5bf190f10b.jpg',
#   'latitude': '-8.414750',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.315955',
#   'tags': [''],
#   'label': ['Body of water',
#    'Coast',
#    'Shore',
#    'Sea',
#    'Beach',
#    'Ocean',
#    'Horizon',
#    'Nature',
#    'Wave',
#    'Sky']},
#  '19442518008': {'url': 'https://live.staticflickr.com/3812/19442518008_10cb2dd85a.jpg',
#   'latitude': '-8.163138',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '114.437003',
#   'tags': [''],
#   'label': ['Sea',
#    'Sky',
#    'Water',
#    'Water transportation',
#    'Boating',
#    'Recreation',
#    'Beach',
#    'Vehicle',
#    'Wave',
#    'Vacation']},
#  '27572605300': {'url': 'https://live.staticflickr.com/7351/27572605300_7e45f8fe97.jpg',
#   'latitude': '-8.282648',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.364111',
#   'tags': [''],
#   'label': ['Water',
#    'Beauty',
#    'Sky',
#    'Sea',
#    'Summer',
#    'Vacation',
#    'Beach',
#    'Leg',
#    'Coast',
#    'Shore']},
#  '26730393107': {'url': 'https://live.staticflickr.com/840/26730393107_8ba1255abb.jpg',
#   'latitude': '-8.298675',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.178272',
#   'tags': ['baturiti', ''],
#   'label': ['Outdoor furniture',
#    'Table',
#    'Outdoor table',
#    'Furniture',
#    'Vacation',
#    'Resort',
#    'Shore',
#    'Tree',
#    'Picnic table',
#    'Beach']},
#  '23312534541': {'url': 'https://live.staticflickr.com/5805/23312534541_fe2610fd87.jpg',
#   'latitude': '-8.246552',
#   'county': 'Karang Asem',
#   'longitude': '115.572738',
#   'tags': ['olympus', 'epl5', 'underwater', 'dive', 'diving', 'tulamben', ''],
#   'label': ['Beach',
#    'Shore',
#    'Coast',
#    'Sea',
#    'Sand',
#    'Natural environment',
#    'Vacation',
#    'Summer',
#    'Coastal and oceanic landforms',
#    'Tree']},
#  '19282104350': {'url': 'https://live.staticflickr.com/3850/19282104350_edc411f5b8.jpg',
#   'latitude': '-8.479167',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.260555',
#   'tags': ['2015',
#    'april',
#    'ubud',
#    'перезагрузка',
#    'перезагрузканабали',
#    'бали',
#    'убуд',
#    ''],
#   'label': ['Sky',
#    'Horizon',
#    'Body of water',
#    'Sea',
#    'Ocean',
#    'Beach',
#    'Cloud',
#    'Sunset',
#    'Evening',
#    'Morning']},
#  '46811914195': {'url': 'https://live.staticflickr.com/65535/46811914195_a707b35801.jpg',
#   'latitude': '-8.496353',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.253455',
#   'tags': ['asia', 'hindu', 'templeparade', 'ubud', ''],
#   'label': ['Sky',
#    'Horizon',
#    'Cloud',
#    'Sea',
#    'Sun',
#    'Ocean',
#    'Beach',
#    'Light',
#    'Sunrise',
#    'Coast']},
#  '45019821201': {'url': 'https://live.staticflickr.com/1970/45019821201_d662ee54cc.jpg',
#   'latitude': '-8.330062',
#   'county': 'Bangli Kabupaten',
#   'longitude': '115.229463',
#   'tags': ['nungnung', 'nungnungwaterfall', ''],
#   'label': ['Body of water',
#    'Beach',
#    'Coast',
#    'Shore',
#    'Sea',
#    'Coastal and oceanic landforms',
#    'Bay',
#    'Sand',
#    'Water resources',
#    'Water']},
#  '24378089543': {'url': 'https://live.staticflickr.com/1595/24378089543_6db15e502c.jpg',
#   'latitude': '-8.412450',
#   'county': 'Karang Asem',
#   'longitude': '115.586783',
#   'tags': ['tirta', 'gangga', ''],
#   'label': ['Public space',
#    'Tourism',
#    'Leisure',
#    'Tree',
#    'Market',
#    'Vacation',
#    'Travel',
#    'Beach']},
#  '47247569991': {'url': 'https://live.staticflickr.com/7918/47247569991_79a0ef0d67.jpg',
#   'latitude': '-8.432500',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.278611',
#   'tags': [''],
#   'label': ['Body of water',
#    'Beach',
#    'Sky',
#    'Shore',
#    'Sea',
#    'Water',
#    'Coast',
#    'Ocean',
#    'Natural landscape',
#    'Natural environment']},
#  '45616770442': {'url': 'https://live.staticflickr.com/1969/45616770442_0c43827191.jpg',
#   'latitude': '-8.275278',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.166388',
#   'tags': ['baturiti',
#    'ancient',
#    'asia',
#    'asian',
#    'attraction',
#    'background',
#    'beautiful',
#    'beratan',
#    'boat',
#    'bratan',
#    'building',
#    'culture',
#    'danu',
#    'destination',
#    'exotic',
#    'hindu',
#    'history',
#    'island',
#    'lake',
#    'landmark',
#    'landscape',
#    'light',
#    'mirror',
#    'nature',
#    'outdoor',
#    'pray',
#    'pura',
#    'reflection',
#    'religious',
#    'river',
#    'scenery',
#    'serene',
#    'sky',
#    'summer',
#    'sunrise',
#    'temple',
#    'tourism',
#    'traditional',
#    'tranquility',
#    'travel',
#    'tropical',
#    'ulun',
#    'water',
#    'worship',
#    ''],
#   'label': ['Beach',
#    'Sea',
#    'Sky',
#    'Coast',
#    'Ocean',
#    'Sand',
#    'Shore',
#    'Vacation',
#    'Coastal and oceanic landforms',
#    'Horizon']},
#  '19274101568': {'url': 'https://live.staticflickr.com/428/19274101568_748b12b6af.jpg',
#   'latitude': '-8.396196',
#   'county': 'Karang Asem',
#   'longitude': '115.428361',
#   'tags': [''],
#   'label': ['Body of water',
#    'Beach',
#    'Coast',
#    'Shore',
#    'Sea',
#    'Sky',
#    'Coastal and oceanic landforms',
#    'Sand',
#    'Ocean',
#    'Property']},
#  '19711871651': {'url': 'https://live.staticflickr.com/3740/19711871651_24e3c8fb44.jpg',
#   'latitude': '-8.147809',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '114.663583',
#   'tags': ['lark', ''],
#   'label': ['Sky',
#    'Sea',
#    'Shore',
#    'Vacation',
#    'Beach',
#    'Summer',
#    'Ocean',
#    'Coast',
#    'Room',
#    'Photography']},
#  '32785125367': {'url': 'https://live.staticflickr.com/65535/32785125367_1dcd92d67a.jpg',
#   'latitude': '-8.496353',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.253455',
#   'tags': ['asia', 'hindu', 'templeparade', 'ubud', ''],
#   'label': ['Body of water',
#    'Sea',
#    'Coast',
#    'Horizon',
#    'Shore',
#    'Water',
#    'Ocean',
#    'Sky',
#    'Waterway',
#    'Beach']},
#  '27861691292': {'url': 'https://live.staticflickr.com/7324/27861691292_b7968313a5.jpg',
#   'latitude': '-8.329702',
#   'county': 'Bangli Kabupaten',
#   'longitude': '115.230091',
#   'tags': ['cascada',
#    'juanjors',
#    'cascadanungnung',
#    'agua',
#    'rio',
#    'arboles',
#    'airelibre',
#    'sol',
#    'asía',
#    'selva',
#    'waterfall',
#    'catarata',
#    ''],
#   'label': ['Scooter',
#    'Vespa',
#    'Vehicle',
#    'Beach',
#    'Vacation',
#    'Fun',
#    'Summer',
#    'Tourism',
#    'Wheel',
#    'Sand']},
#  '28761804942': {'url': 'https://live.staticflickr.com/8688/28761804942_29db69d2a4.jpg',
#   'latitude': '-8.414675',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.316138',
#   'tags': [''],
#   'label': ['Beach',
#    'Umbrella',
#    'Sand',
#    'Coast',
#    'Tourism',
#    'Shore',
#    'Vacation',
#    'Travel',
#    'Sea',
#    'Ocean']},
#  '38956544860': {'url': 'https://live.staticflickr.com/4797/38956544860_bf718cff2c.jpg',
#   'latitude': '-8.131653',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '114.655922',
#   'tags': ['scorpionfishflatheads',
#    'photography',
#    'tasseledscorpionfish',
#    'typeofphotography',
#    'scorpionfishes',
#    'underwaterphotography',
#    'biowreck',
#    'animals',
#    'pemuteran',
#    'fish',
#    'divesites',
#    'scorpaeniformes',
#    'scorpaenopsisoxycephala',
#    'smallscalescorpionfish',
#    ''],
#   'label': ['Sky',
#    'Beach',
#    'Sea',
#    'Cloud',
#    'Coast',
#    'Sand',
#    'Ocean',
#    'Horizon',
#    'Shore',
#    'Water']},
#  '22997698645': {'url': 'https://live.staticflickr.com/615/22997698645_29bff0b445.jpg',
#   'latitude': '-8.277109',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.378444',
#   'tags': [''],
#   'label': ['Body of water',
#    'Coast',
#    'Water resources',
#    'Water',
#    'Shore',
#    'Sea',
#    'Beach',
#    'Coastal and oceanic landforms',
#    'Ocean',
#    'Headland']},
#  '33950304586': {'url': 'https://live.staticflickr.com/2851/33950304586_d2da83289c.jpg',
#   'latitude': '-8.499423',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.266402',
#   'tags': [''],
#   'label': ['Beach',
#    'Sky',
#    'Sea',
#    'Sand',
#    'Shore',
#    'Coast',
#    'Vacation',
#    'Vehicle',
#    'Tropics',
#    'Ocean']},
#  '43208059620': {'url': 'https://live.staticflickr.com/1918/43208059620_4c11da02c1.jpg',
#   'latitude': '-8.414387',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.315947',
#   'tags': ['puratirtaempul', 'tirtaempul', ''],
#   'label': ['Hair',
#    'Hairstyle',
#    'Long hair',
#    'Vacation',
#    'Sea',
#    'Blond',
#    'Summer',
#    'Rock',
#    'Coast',
#    'Beach']},
#  '30535489304': {'url': 'https://live.staticflickr.com/5484/30535489304_14429ec0fe.jpg',
#   'latitude': '-8.165409',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.016813',
#   'tags': ['banjar', 'id', ''],
#   'label': ['Body of water',
#    'Beach',
#    'Coast',
#    'Shore',
#    'Vacation',
#    'Sea',
#    'Caribbean',
#    'Ocean',
#    'Coastal and oceanic landforms',
#    'Tourism']},
#  '25626890991': {'url': 'https://live.staticflickr.com/1467/25626890991_8230215980.jpg',
#   'latitude': '-8.154813',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.032958',
#   'tags': [''],
#   'label': ['Body of water',
#    'Sea',
#    'Ocean',
#    'Coast',
#    'Sky',
#    'Shore',
#    'Beach',
#    'Coastal and oceanic landforms',
#    'Wave',
#    'Horizon']},
#  '21593985704': {'url': 'https://live.staticflickr.com/5755/21593985704_ed1806b615.jpg',
#   'latitude': '-8.278908',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.156425',
#   'tags': ['bedugul',
#    'laniidae',
#    'laniusschach',
#    'longtailedshrike',
#    'birds',
#    'shrikes',
#    ''],
#   'label': ['Body of water',
#    'Beach',
#    'Sky',
#    'Horizon',
#    'Sea',
#    'Shore',
#    'Coast',
#    'Ocean',
#    'Cloud',
#    'Vacation']},
#  '27999470056': {'url': 'https://live.staticflickr.com/7618/27999470056_57f0414116.jpg',
#   'latitude': '-8.422742',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.278694',
#   'tags': [''],
#   'label': ['Body of water',
#    'Beach',
#    'Coast',
#    'Shore',
#    'Sea',
#    'Ocean',
#    'Sky',
#    'Wave',
#    'Coastal and oceanic landforms',
#    'Headland']},
#  '44587924434': {'url': 'https://live.staticflickr.com/1923/44587924434_7ba753e777.jpg',
#   'latitude': '-8.363106',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.140108',
#   'tags': [''],
#   'label': ['Body of water',
#    'Coast',
#    'Sea',
#    'Sky',
#    'Beach',
#    'Ocean',
#    'Shore',
#    'Caribbean',
#    'Coastal and oceanic landforms',
#    'Natural landscape']},
#  '29598225130': {'url': 'https://live.staticflickr.com/5253/29598225130_7dc7d319e1.jpg',
#   'latitude': '-8.475960',
#   'county': 'Bangli Kabupaten',
#   'longitude': '115.323888',
#   'tags': ['clarendon', ''],
#   'label': ['Sky',
#    'Horizon',
#    'Sunset',
#    'Sunrise',
#    'Sea',
#    'Cloud',
#    'Ocean',
#    'Evening',
#    'Beach',
#    'Sun']},
#  '27466229440': {'url': 'https://live.staticflickr.com/7303/27466229440_9df01c15fa.jpg',
#   'latitude': '-8.282141',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.385348',
#   'tags': ['2015',
#    'baturbaguscottage',
#    'kintamani',
#    'kedisan',
#    'kampung',
#    'desa',
#    'village',
#    'banjar',
#    'temple',
#    'pura',
#    'celebration',
#    'ceremony',
#    'traditional',
#    'traditionaldress',
#    'tradition',
#    'asli',
#    'women',
#    'men',
#    'girls',
#    'kebaya',
#    'kamen',
#    'offerings',
#    'colourful',
#    'baturbaguscottages',
#    'indra',
#    'fotograph',
#    ''],
#   'label': ['Sky',
#    'Water',
#    'Ocean',
#    'Cloud',
#    'Sea',
#    'Beach',
#    'Tourism',
#    'Vacation',
#    'Mountain',
#    'Horizon']},
#  '19501183749': {'url': 'https://live.staticflickr.com/288/19501183749_e5bdfccd54.jpg',
#   'latitude': '-8.148360',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '114.660047',
#   'tags': ['ludwig', ''],
#   'label': ['People on beach',
#    'Beach',
#    'Tourism',
#    'Vacation',
#    'Coast',
#    'Shore',
#    'Fun',
#    'Leisure',
#    'Bay',
#    'Coastal and oceanic landforms']},
#  '31414757296': {'url': 'https://live.staticflickr.com/5495/31414757296_f2617bf3e2.jpg',
#   'latitude': '-8.415939',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.315416',
#   'tags': ['travel', 'wander', 'tampaksiring', 'id', ''],
#   'label': ['Beach',
#    'Vacation',
#    'Sea',
#    'Caribbean',
#    'Turquoise',
#    'Sky',
#    'Coast',
#    'Tropics',
#    'Tourism',
#    'Resort']},
#  '35972394100': {'url': 'https://live.staticflickr.com/4295/35972394100_87584f560a.jpg',
#   'latitude': '-8.378403',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134466',
#   'tags': [''],
#   'label': ['Vacation',
#    'Beach',
#    'Fun',
#    'Summer',
#    'Tourism',
#    'Muscle',
#    'Recreation',
#    'Leisure',
#    'Sun tanning',
#    'Spring break']},
#  '35970446740': {'url': 'https://live.staticflickr.com/4425/35970446740_63fff572b2.jpg',
#   'latitude': '-8.378403',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134466',
#   'tags': [''],
#   'label': ['Body of water',
#    'Natural landscape',
#    'Sky',
#    'Coast',
#    'Nature',
#    'Shore',
#    'Sea',
#    'Ocean',
#    'Coastal and oceanic landforms',
#    'Beach']},
#  '27659729432': {'url': 'https://live.staticflickr.com/7378/27659729432_457963b599.jpg',
#   'latitude': '-8.282141',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.385348',
#   'tags': ['2015',
#    'baturbaguscottage',
#    'kintamani',
#    'kedisan',
#    'kampung',
#    'desa',
#    'village',
#    'banjar',
#    'temple',
#    'pura',
#    'celebration',
#    'ceremony',
#    'traditional',
#    'traditionaldress',
#    'tradition',
#    'asli',
#    'women',
#    'men',
#    'girls',
#    'kebaya',
#    'kamen',
#    'offerings',
#    'colourful',
#    'umbrella',
#    'baturbaguscottages',
#    'indra',
#    'fotograph',
#    ''],
#   'label': ['Sun tanning',
#    'Vacation',
#    'Leisure',
#    'Tourism',
#    'Resort',
#    'Beach',
#    'Palm tree',
#    'Summer',
#    'Tree',
#    'Fun']},
#  '23626301624': {'url': 'https://live.staticflickr.com/1457/23626301624_4a5520bb95.jpg',
#   'latitude': '-8.263178',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.420954',
#   'tags': ['asia',
#    'village',
#    'tomfrohnhofer',
#    'cemetery',
#    'funeral',
#    'spooky',
#    'bodies',
#    '2016',
#    'dead',
#    'trunyan',
#    ''],
#   'label': ['Body of water',
#    'Sky',
#    'Beach',
#    'Horizon',
#    'Sea',
#    'Ocean',
#    'Wave',
#    'Shore',
#    'Coast',
#    'Water']},
#  '36243706251': {'url': 'https://live.staticflickr.com/4391/36243706251_a001e89901.jpg',
#   'latitude': '-8.378403',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134466',
#   'tags': [''],
#   'label': ['Sea',
#    'Beach',
#    'Vacation',
#    'Tropics',
#    'Sky',
#    'Tree',
#    'Shore',
#    'Ocean',
#    'Resort',
#    'Coast']},
#  '35970445950': {'url': 'https://live.staticflickr.com/4422/35970445950_2ed5c235d7.jpg',
#   'latitude': '-8.378403',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134466',
#   'tags': [''],
#   'label': ['Body of water',
#    'Natural landscape',
#    'Shore',
#    'Coast',
#    'Nature',
#    'Nature reserve',
#    'Beach',
#    'Vegetation',
#    'Natural environment',
#    'Water']},
#  '36394409456': {'url': 'https://live.staticflickr.com/4409/36394409456_991cfe9646.jpg',
#   'latitude': '-8.378403',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134466',
#   'tags': [''],
#   'label': ['Sky',
#    'Cloud',
#    'Beach',
#    'Coast',
#    'Sea',
#    'Shore',
#    'Tree',
#    'Tourism',
#    'Bank',
#    'Photography']},
#  '36303007961': {'url': 'https://live.staticflickr.com/4423/36303007961_282c3dd005.jpg',
#   'latitude': '-8.378403',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134466',
#   'tags': [''],
#   'label': ['Coast',
#    'Shore',
#    'Beach',
#    'Sea',
#    'Ocean',
#    'Fun',
#    'Coastal and oceanic landforms',
#    'Vacation']},
#  '23689826176': {'url': 'https://live.staticflickr.com/5719/23689826176_23e8198a95.jpg',
#   'latitude': '-8.142628',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.050997',
#   'tags': ['frog', 'kikker', 'buleleng', ''],
#   'label': ['Vacation',
#    'Tourism',
#    'Leisure',
#    'Travel',
#    'Fun',
#    'Adaptation',
#    'Temple',
#    'Beach']},
#  '18841239314': {'url': 'https://live.staticflickr.com/390/18841239314_38836ccc8d.jpg',
#   'latitude': '-8.469446',
#   'county': 'Karang Asem',
#   'longitude': '115.409813',
#   'tags': [''],
#   'label': ['Sky',
#    'Blue',
#    'Vacation',
#    'Water',
#    'Beach',
#    'Ocean',
#    'Sea',
#    'Cloud',
#    'Summer',
#    'Caribbean']},
#  '40159353110': {'url': 'https://live.staticflickr.com/827/40159353110_f4541ceff5.jpg',
#   'latitude': '-8.478987',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.251938',
#   'tags': [''],
#   'label': ['Beach',
#    'Coast',
#    'Sand',
#    'Shore',
#    'Sea',
#    'Sky',
#    'Ocean',
#    'Fun',
#    'Tourism',
#    'Coastal and oceanic landforms']},
#  '30371114517': {'url': 'https://live.staticflickr.com/1954/30371114517_e5da3d78f1.jpg',
#   'latitude': '-8.372320',
#   'county': 'Karang Asem',
#   'longitude': '115.452580',
#   'tags': [''],
#   'label': ['Sky',
#    'Cloud',
#    'Beach',
#    'Sea',
#    'Blue',
#    'Horizon',
#    'Ocean',
#    'Daytime',
#    'Cumulus',
#    'Sand']},
#  '35559086113': {'url': 'https://live.staticflickr.com/4415/35559086113_f7aa1cc8f9.jpg',
#   'latitude': '-8.378403',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134466',
#   'tags': [''],
#   'label': ['Body of water',
#    'Coast',
#    'Sea',
#    'Shore',
#    'Water',
#    'Coastal and oceanic landforms',
#    'Beach',
#    'Water resources',
#    'Ocean',
#    'Inlet']},
#  '36198905262': {'url': 'https://live.staticflickr.com/4349/36198905262_45247e04fc.jpg',
#   'latitude': '-8.378403',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134466',
#   'tags': [''],
#   'label': ['Body of water',
#    'Coast',
#    'Sea',
#    'Shore',
#    'Coastal and oceanic landforms',
#    'Beach',
#    'Bay',
#    'Headland',
#    'Ocean',
#    'Inlet']},
#  '35970446460': {'url': 'https://live.staticflickr.com/4426/35970446460_46b99b3683.jpg',
#   'latitude': '-8.378403',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134466',
#   'tags': [''],
#   'label': ['Body of water',
#    'Water resources',
#    'Coast',
#    'Shore',
#    'Water',
#    'Sea',
#    'Beach',
#    'Natural landscape',
#    'Coastal and oceanic landforms',
#    'River']},
#  '35970445670': {'url': 'https://live.staticflickr.com/4360/35970445670_cafc4f3067.jpg',
#   'latitude': '-8.378403',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134466',
#   'tags': [''],
#   'label': ['Shore',
#    'Vegetation',
#    'Natural landscape',
#    'Coast',
#    'Natural environment',
#    'Nature reserve',
#    'Sea',
#    'Beach',
#    'Coastal and oceanic landforms',
#    'Grass']},
#  '23880551451': {'url': 'https://live.staticflickr.com/5793/23880551451_6671457203.jpg',
#   'latitude': '-8.499637',
#   'county': 'Karang Asem',
#   'longitude': '115.536736',
#   'tags': ['thesearemyfriends',
#    'groupselfie',
#    'selfie✌',
#    'selfiegroup',
#    'smile✌',
#    'happy',
#    'happypeople',
#    'checkthisout',
#    'family',
#    'traveling',
#    'travel',
#    'realpeople',
#    ''],
#   'label': ['Beach',
#    'Tree',
#    'Palm tree',
#    'Vacation',
#    'Resort',
#    'Caribbean',
#    'Arecales',
#    'Tourism',
#    'Tropics',
#    'Shore']},
#  '16344991001': {'url': 'https://live.staticflickr.com/8648/16344991001_cc313b5ec0.jpg',
#   'latitude': '-8.098755',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.096410',
#   'tags': [''],
#   'label': ['Beach',
#    'Shore',
#    'Coast',
#    'Sea',
#    'Sky',
#    'Boat',
#    'Ocean',
#    'Vehicle',
#    'Vacation',
#    'Tree']},
#  '21595754183': {'url': 'https://live.staticflickr.com/5782/21595754183_1d929399de.jpg',
#   'latitude': '-8.246436',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.162652',
#   'tags': ['bedugul',
#    'capitonidae',
#    'flamefrontedbarbet',
#    'oldworldbarbets',
#    'psilopogonarmillaris',
#    ''],
#   'label': ['Horizon',
#    'Body of water',
#    'Sky',
#    'Sea',
#    'Beach',
#    'Ocean',
#    'Sunset',
#    'Cloud',
#    'Sunrise',
#    'Coast']},
#  '22203996662': {'url': 'https://live.staticflickr.com/630/22203996662_ace164f944.jpg',
#   'latitude': '-8.273258',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.152365',
#   'tags': ['bedugul',
#    'javanwhistlingthrush',
#    'myophonusglaucinus',
#    'thrushesandallies',
#    'turdidae',
#    'birds',
#    'thrushes',
#    ''],
#   'label': ['Sky',
#    'Beach',
#    'Sand',
#    'Sea',
#    'Horizon',
#    'Shore',
#    'Landscape',
#    'Coast',
#    'Calm',
#    'Tree']},
#  '22028971188': {'url': 'https://live.staticflickr.com/5758/22028971188_00d0dbc272.jpg',
#   'latitude': '-8.279375',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.156736',
#   'tags': ['bedugul',
#    'javangraythroatedwhiteeye',
#    'lophozosteropsjavanicus',
#    'yuhinaswhiteeyedandallies',
#    'zosteropidae',
#    ''],
#   'label': ['Sea',
#    'Sky',
#    'Wave',
#    'Ocean',
#    'Beach',
#    'Shore',
#    'Coast',
#    'Calm',
#    'Vacation',
#    'Sand']},
#  '27476340948': {'url': 'https://live.staticflickr.com/894/27476340948_fdec513611.jpg',
#   'latitude': '-8.493981',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.277969',
#   'tags': ['blog', 'blogg', 'viceroy', ''],
#   'label': ['Body of water',
#    'Coast',
#    'Sea',
#    'Shore',
#    'Beach',
#    'Promontory',
#    'Coastal and oceanic landforms',
#    'Ocean',
#    'Headland',
#    'Rock']},
#  '44971923672': {'url': 'https://live.staticflickr.com/1912/44971923672_a63835be64.jpg',
#   'latitude': '-8.315956',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.336911',
#   'tags': [''],
#   'label': ['Shore',
#    'Beach',
#    'Coast',
#    'Sea',
#    'Tree',
#    'Coastal and oceanic landforms',
#    'Sand',
#    'Soil',
#    'Bank',
#    'Landscape']},
#  '29211865412': {'url': 'https://live.staticflickr.com/8518/29211865412_da2d4fa288.jpg',
#   'latitude': '-8.489516',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.257805',
#   'tags': [''],
#   'label': ['Nature',
#    'Sea',
#    'Shore',
#    'Sky',
#    'Natural landscape',
#    'Coast',
#    'Ocean',
#    'Beach',
#    'Tropics',
#    'Cloud']},
#  '28687382644': {'url': 'https://live.staticflickr.com/8377/28687382644_d5bf174560.jpg',
#   'latitude': '-8.494522',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.256086',
#   'tags': [''],
#   'label': ['Beach',
#    'Body of water',
#    'Coast',
#    'Shore',
#    'Sea',
#    'Sand',
#    'Ocean',
#    'Sky',
#    'Coastal and oceanic landforms',
#    'Natural environment']},
#  '36367467175': {'url': 'https://live.staticflickr.com/4378/36367467175_15789dc2df.jpg',
#   'latitude': '-8.378403',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134466',
#   'tags': [''],
#   'label': ['Sea',
#    'Coast',
#    'Shore',
#    'Ocean',
#    'Coastal and oceanic landforms',
#    'Rock',
#    'Wave',
#    'Beach',
#    'Breakwater']},
#  '35983890140': {'url': 'https://live.staticflickr.com/4366/35983890140_384a485c24.jpg',
#   'latitude': '-8.378403',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134466',
#   'tags': [''],
#   'label': ['Vacation',
#    'Tourism',
#    'Fun',
#    'Travel',
#    'Leisure',
#    'Summer',
#    'Sea',
#    'Beach',
#    'Event',
#    'Ocean']},
#  '35970441540': {'url': 'https://live.staticflickr.com/4416/35970441540_54e2b72ca3.jpg',
#   'latitude': '-8.378403',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134466',
#   'tags': [''],
#   'label': ['Vegetation',
#    'Coast',
#    'Ocean',
#    'Sea',
#    'Shore',
#    'Natural landscape',
#    'Coastal and oceanic landforms',
#    'Beach',
#    'Caribbean',
#    'Sky']},
#  '23098875514': {'url': 'https://live.staticflickr.com/5729/23098875514_f9094d108c.jpg',
#   'latitude': '-8.157181',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.001119',
#   'tags': ['dolfijn', 'dolphin', 'kecamatanbuleleng', ''],
#   'label': ['Pole',
#    'Fun',
#    'Tourism',
#    'Event',
#    'Tradition',
#    'Leisure',
#    'Vacation',
#    'Beach']},
#  '33260255176': {'url': 'https://live.staticflickr.com/3844/33260255176_a4d20b0226.jpg',
#   'latitude': '-8.416062',
#   'county': 'Bangli Kabupaten',
#   'longitude': '115.238256',
#   'tags': ['forest', 'green', 'steps', 'rural', ''],
#   'label': ['Sky',
#    'Sea',
#    'Blue',
#    'Ocean',
#    'Cloud',
#    'Beach',
#    'Water',
#    'Horizon',
#    'Coast',
#    'Wave']},
#  '39539177520': {'url': 'https://live.staticflickr.com/810/39539177520_ee1b5879db.jpg',
#   'latitude': '-8.494356',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.278213',
#   'tags': ['2018', 'trip', 'vacation', 'blog', 'blogg', 'viceroy', ''],
#   'label': ['Beach',
#    'Sand',
#    'Shore',
#    'Coast',
#    'Sea',
#    'Natural environment',
#    'Raised beach',
#    'Mudflat',
#    'Ocean',
#    'Coastal and oceanic landforms']},
#  '30082937647': {'url': 'https://live.staticflickr.com/1918/30082937647_39c5705401.jpg',
#   'latitude': '-8.423287',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.310666',
#   'tags': ['gunungkawi', ''],
#   'label': ['Coast',
#    'Vacation',
#    'Sea',
#    'Beach',
#    'Tourism',
#    'Fun',
#    'Shore',
#    'Cape',
#    'Summer',
#    'Coastal and oceanic landforms']},
#  '43208344160': {'url': 'https://live.staticflickr.com/1940/43208344160_b795e60a02.jpg',
#   'latitude': '-8.423287',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.310666',
#   'tags': ['gunungkawi', ''],
#   'label': ['Coast',
#    'Vacation',
#    'Tourism',
#    'Sea',
#    'Coastal and oceanic landforms',
#    'Promontory',
#    'Bay',
#    'Cape',
#    'Beach',
#    'Headland']},
#  '46885863434': {'url': 'https://live.staticflickr.com/7923/46885863434_552e2b48b9.jpg',
#   'latitude': '-8.146370',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.043742',
#   'tags': ['sunset',
#    'sea',
#    'seascape',
#    'seashore',
#    'colour',
#    'clouds',
#    'water',
#    'reflection',
#    'leica',
#    'leicadluxtyp109',
#    'purple',
#    'beach',
#    'sky',
#    'light',
#    'dlux',
#    'rwscholte',
#    ''],
#   'label': ['Mode of transport',
#    'Vehicle',
#    'Transport',
#    'Tourism',
#    'Vacation',
#    'Summer',
#    'Beach',
#    'Travel',
#    'Scooter',
#    'Bridge']},
#  '22505708885': {'url': 'https://live.staticflickr.com/703/22505708885_fac1306b57.jpg',
#   'latitude': '-8.260770',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.068816',
#   'tags': [''],
#   'label': ['Body of water',
#    'Shore',
#    'Sea',
#    'Coast',
#    'Ocean',
#    'Water',
#    'Coastal and oceanic landforms',
#    'Beach',
#    'Natural environment',
#    'Water resources']},
#  '40342421471': {'url': 'https://live.staticflickr.com/4678/40342421471_4fa5c0c6ef.jpg',
#   'latitude': '-8.357867',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.300047',
#   'tags': [''],
#   'label': ['Beach',
#    'Body of water',
#    'Coast',
#    'Sea',
#    'Shore',
#    'Sky',
#    'Sand',
#    'Ocean',
#    'Coastal and oceanic landforms',
#    'Water']},
#  '40342418601': {'url': 'https://live.staticflickr.com/4769/40342418601_28c9e61daa.jpg',
#   'latitude': '-8.357842',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.300016',
#   'tags': [''],
#   'label': ['Vacation',
#    'Travel',
#    'Summer',
#    'Tourism',
#    'Leisure',
#    'Fun',
#    'Beach',
#    'Sea',
#    'Resort',
#    'Ocean']},
#  '43152817150': {'url': 'https://live.staticflickr.com/1963/43152817150_9129fe831f.jpg',
#   'latitude': '-8.315964',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.336986',
#   'tags': [''],
#   'label': ['Body of water',
#    'Blue',
#    'Beach',
#    'Sea',
#    'Sky',
#    'Shore',
#    'Ocean',
#    'Coast',
#    'Turquoise',
#    'Water']},
#  '35970442130': {'url': 'https://live.staticflickr.com/4380/35970442130_29895dc7c6.jpg',
#   'latitude': '-8.378403',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134466',
#   'tags': [''],
#   'label': ['Wave',
#    'Ocean',
#    'Coast',
#    'Shore',
#    'Sea',
#    'Beach',
#    'Wind wave',
#    'Tide',
#    'Vacation',
#    'Sky']},
#  '36439409815': {'url': 'https://live.staticflickr.com/4401/36439409815_71e8bcf164.jpg',
#   'latitude': '-8.378403',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134466',
#   'tags': [''],
#   'label': ['Body of water',
#    'Water',
#    'Water resources',
#    'Waterway',
#    'Sky',
#    'River',
#    'Sea',
#    'Dock',
#    'Beach',
#    'Coast']},
#  '26957545761': {'url': 'https://live.staticflickr.com/7218/26957545761_68b430b77c.jpg',
#   'latitude': '-8.282141',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.385348',
#   'tags': ['2015',
#    'kintamani',
#    'kedisan',
#    'kampung',
#    'keluarga',
#    'kebaya',
#    'village',
#    'pura',
#    'temple',
#    'hindu',
#    'agama',
#    'ceremony',
#    'offerings',
#    'permangku',
#    'priests',
#    'prayer',
#    'blessing',
#    'umbrella',
#    'udeng',
#    'mountbatur',
#    'lakebatur',
#    'gunungbatur',
#    'desa',
#    'mountain',
#    'men',
#    'women',
#    'sarong',
#    'fruit',
#    'colourful',
#    'colour',
#    'carrying',
#    'statue',
#    'stonecarving',
#    'stonestatue',
#    'oldwoman',
#    'old',
#    'oldman',
#    ''],
#   'label': ['Water',
#    'Shore',
#    'Sky',
#    'Coast',
#    'Sea',
#    'Ocean',
#    'Beach',
#    'Tide',
#    'Recreation',
#    'Vacation']},
#  '27149419923': {'url': 'https://live.staticflickr.com/7384/27149419923_90b2ccdd54.jpg',
#   'latitude': '-8.282141',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.385348',
#   'tags': ['2015',
#    'baturbaguscottage',
#    'kintamani',
#    'kedisan',
#    'kampung',
#    'desa',
#    'village',
#    'banjar',
#    'temple',
#    'pura',
#    'celebration',
#    'ceremony',
#    'traditional',
#    'traditionaldress',
#    'tradition',
#    'asli',
#    'women',
#    'men',
#    'girls',
#    'kebaya',
#    'kamen',
#    'offerings',
#    'colourful',
#    'umbrella',
#    'baturbaguscottages',
#    'indra',
#    'fotograph',
#    ''],
#   'label': ['Sky',
#    'Sea',
#    'Horizon',
#    'Ocean',
#    'Sunset',
#    'Beach',
#    'Sunrise',
#    'Water',
#    'Wave',
#    'Shore']},
#  '46272907942': {'url': 'https://live.staticflickr.com/4831/46272907942_7ac90afd6c.jpg',
#   'latitude': '-8.430834',
#   'county': 'Karang Asem',
#   'longitude': '115.555833',
#   'tags': ['drone',
#    'aerialview',
#    'woman',
#    'summer',
#    'man',
#    'lifestyle',
#    'person',
#    'happy',
#    'field',
#    'ricefield',
#    'nature',
#    'park',
#    'female',
#    'landscape',
#    'relax',
#    'outdoor',
#    'view',
#    'garden',
#    'journey',
#    'holiday',
#    'style',
#    'asia',
#    'travel',
#    'countryside',
#    'rice',
#    'sunlight',
#    'camera',
#    'bright',
#    'tropical',
#    'mountain',
#    'agriculture',
#    'backpack',
#    'sapling',
#    'health',
#    'village',
#    'lover',
#    'people',
#    'young',
#    'happiness',
#    'hat',
#    'vacation',
#    'leisure',
#    'love',
#    'adventure',
#    ''],
#   'label': ['Sun tanning',
#    'Vacation',
#    'Beach',
#    'Leisure',
#    'Sunlounger',
#    'Summer',
#    'Resort',
#    'Travel',
#    'Tourism',
#    'Fun']},
#  '19439439559': {'url': 'https://live.staticflickr.com/468/19439439559_ec74faa5f2.jpg',
#   'latitude': '-8.134803',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '114.534425',
#   'tags': [''],
#   'label': ['Beach',
#    'Fun',
#    'Canidae',
#    'Vacation',
#    'Dog',
#    'Summer',
#    'Human',
#    'Dog walking',
#    'Leash',
#    'Leg']},
#  '39539179050': {'url': 'https://live.staticflickr.com/796/39539179050_13969b3b26.jpg',
#   'latitude': '-8.494045',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.278030',
#   'tags': ['2018', 'trip', 'vacation', 'blog', 'blogg', 'viceroy', ''],
#   'label': ['Beach',
#    'Shore',
#    'Coast',
#    'Sea',
#    'Natural environment',
#    'Sand',
#    'Ocean',
#    'Coastal and oceanic landforms',
#    'Sky',
#    'Soil']},
#  '22614072833': {'url': 'https://live.staticflickr.com/770/22614072833_f4c48d2b20.jpg',
#   'latitude': '-8.098256',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '114.511463',
#   'tags': ['menjangan', 'island', 'diving', 'beach', 'boat', 'java', ''],
#   'label': ['White',
#    'Black',
#    'Photograph',
#    'Atmospheric phenomenon',
#    'Standing',
#    'Sky',
#    'Sand',
#    'Sea',
#    'Beach',
#    'Fog']},
#  '26422795264': {'url': 'https://live.staticflickr.com/7736/26422795264_947ed1781b.jpg',
#   'latitude': '-8.282141',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.385348',
#   'tags': ['2015',
#    'kintamani',
#    'kedisan',
#    'kampung',
#    'keluarga',
#    'kebaya',
#    'village',
#    'pura',
#    'temple',
#    'hindu',
#    'agama',
#    'ceremony',
#    'offerings',
#    'permangku',
#    'priests',
#    'prayer',
#    'blessing',
#    'umbrella',
#    'udeng',
#    'mountbatur',
#    'lakebatur',
#    'gunungbatur',
#    'desa',
#    'mountain',
#    'men',
#    'women',
#    'sarong',
#    'fruit',
#    'colourful',
#    'colour',
#    'carrying',
#    'statue',
#    'stonecarving',
#    'stonestatue',
#    'oldwoman',
#    'old',
#    'oldman',
#    ''],
#   'label': ['Body of water',
#    'Coast',
#    'Beach',
#    'Shore',
#    'Sea',
#    'Coastal and oceanic landforms',
#    'Bay',
#    'Ocean',
#    'Sky',
#    'Water']},
#  '34658611131': {'url': 'https://live.staticflickr.com/4189/34658611131_4387f33369.jpg',
#   'latitude': '-8.278723',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.380585',
#   'tags': ['kintamani',
#    'kedisan',
#    'baturbaguscottage',
#    'village',
#    'desa',
#    'kampung',
#    'lakebatur',
#    'danaubatur',
#    'mountbatur',
#    'gunungbatur',
#    'giri',
#    'homestay',
#    'lake',
#    'waterscape',
#    'view',
#    'vista',
#    'caldera',
#    'mountain',
#    'mountabang',
#    'nature',
#    'outdoors',
#    'ridge',
#    'sky',
#    'blue',
#    'horticulture',
#    'garden',
#    'lakeside',
#    'vegetables',
#    'communal',
#    'clouds',
#    'volcano',
#    'sunny',
#    ''],
#   'label': ['Body of water',
#    'Coast',
#    'Wave',
#    'Sea',
#    'Shore',
#    'Ocean',
#    'Promontory',
#    'Wind wave',
#    'Coastal and oceanic landforms',
#    'Beach']},
#  '46885862834': {'url': 'https://live.staticflickr.com/7881/46885862834_1cdcd44e2c.jpg',
#   'latitude': '-8.146115',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.045073',
#   'tags': ['blackandwhite',
#    'bw',
#    'monochrome',
#    'minimalism',
#    'dluxtyp109',
#    'leica',
#    'sky',
#    'seascape',
#    'seashore',
#    'sea',
#    'rwscholte',
#    ''],
#   'label': ['Body of water',
#    'Beach',
#    'Coast',
#    'Shore',
#    'Photograph',
#    'Sea',
#    'Horizon',
#    'Sky',
#    'Ocean',
#    'Natural environment']},
#  '28910905272': {'url': 'https://live.staticflickr.com/8048/28910905272_3fde886cf9.jpg',
#   'latitude': '-8.444167',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.278197',
#   'tags': [''],
#   'label': ['Coast',
#    'Beach',
#    'Shore',
#    'Coastal and oceanic landforms',
#    'Sea',
#    'Bay',
#    'Sky',
#    'Ocean',
#    'Vacation',
#    'Promontory']},
#  '39631283234': {'url': 'https://live.staticflickr.com/4606/39631283234_070666cb87.jpg',
#   'latitude': '-8.357867',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.300047',
#   'tags': [''],
#   'label': ['Body of water',
#    'Beach',
#    'Shore',
#    'Coast',
#    'Sea',
#    'Sky',
#    'Natural environment',
#    'Ocean',
#    'Coastal and oceanic landforms',
#    'Sand']},
#  '35970444790': {'url': 'https://live.staticflickr.com/4405/35970444790_f1252e4135.jpg',
#   'latitude': '-8.378403',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134466',
#   'tags': [''],
#   'label': ['Photograph',
#    'Sea',
#    'Vacation',
#    'Tourism',
#    'Ocean',
#    'Beach',
#    'Ceremony',
#    'Coast',
#    'Summer',
#    'Sky']},
#  '36379356441': {'url': 'https://live.staticflickr.com/4440/36379356441_502bfe418d.jpg',
#   'latitude': '-8.378403',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134466',
#   'tags': [''],
#   'label': ['Sky',
#    'Horizon',
#    'Sea',
#    'Ocean',
#    'Beach',
#    'Cloud',
#    'Sunrise',
#    'Coast',
#    'Morning',
#    'Shore']},
#  '45992625464': {'url': 'https://live.staticflickr.com/4833/45992625464_90ecfec065.jpg',
#   'latitude': '-8.449715',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.280077',
#   'tags': ['asia',
#    'blackwhite',
#    'canon',
#    'contrast',
#    'culture',
#    'market',
#    'pasar',
#    'orang',
#    'perempuan',
#    'eos',
#    '7d',
#    '2018',
#    'street',
#    'streetlife',
#    'streetphotography',
#    'timing',
#    'vignette',
#    ''],
#   'label': ['Flag',
#    'Sky',
#    'Red flag',
#    'Beach',
#    'Vacation',
#    'Cloud',
#    'Wind',
#    'Coast',
#    'Shade']},
#  '34751177676': {'url': 'https://live.staticflickr.com/4222/34751177676_fe1025157d.jpg',
#   'latitude': '-8.278723',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.380585',
#   'tags': ['kintamani',
#    'kedisan',
#    'baturbaguscottage',
#    'village',
#    'desa',
#    'kampung',
#    'lakebatur',
#    'danaubatur',
#    'mountbatur',
#    'gunungbatur',
#    'giri',
#    'homestay',
#    'lake',
#    'waterscape',
#    'view',
#    'vista',
#    'caldera',
#    'mountain',
#    'mountabang',
#    'nature',
#    'outdoors',
#    'ridge',
#    'sky',
#    'blue',
#    'horticulture',
#    'garden',
#    'lakeside',
#    'vegetables',
#    'communal',
#    'clouds',
#    'volcano',
#    'sunset',
#    'pink',
#    'orange',
#    ''],
#   'label': ['Water transportation',
#    'Sky',
#    'Boat',
#    'Sea',
#    'Vehicle',
#    'Ocean',
#    'Coast',
#    'Tree',
#    'Beach',
#    'Vacation']},
#  '29869066382': {'url': 'https://live.staticflickr.com/5708/29869066382_f189a36806.jpg',
#   'latitude': '-8.308216',
#   'county': 'Karang Asem',
#   'longitude': '115.621511',
#   'tags': ['tulamben',
#    'diving',
#    'underwater',
#    'supermacro',
#    'critters',
#    'ghost',
#    'shrimp',
#    'crustacea',
#    'orange',
#    'colorful',
#    'sponge',
#    'blackbackground',
#    'contrast',
#    ''],
#   'label': ['Sky',
#    'White',
#    'Black',
#    'Cloud',
#    'Water',
#    'Black-and-white',
#    'Monochrome photography',
#    'Sea',
#    'Beach',
#    'Ocean']},
#  '40581979983': {'url': 'https://live.staticflickr.com/7887/40581979983_56e6066e2a.jpg',
#   'latitude': '-8.448484',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.262955',
#   'tags': [''],
#   'label': ['Sky',
#    'Beach',
#    'Sea',
#    'Horizon',
#    'Cloud',
#    'Ocean',
#    'Shore',
#    'Morning',
#    'Coast',
#    'Sand']},
#  '31414734036': {'url': 'https://live.staticflickr.com/5667/31414734036_222af0339a.jpg',
#   'latitude': '-8.415939',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.315416',
#   'tags': ['travel', 'wander', 'tampaksiring', 'id', ''],
#   'label': ['Sky',
#    'Nature',
#    'Natural landscape',
#    'Sea',
#    'Shore',
#    'Cloud',
#    'Coast',
#    'Tourism',
#    'Ocean',
#    'Beach']},
#  '35970445060': {'url': 'https://live.staticflickr.com/4435/35970445060_fb10e209fb.jpg',
#   'latitude': '-8.378403',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134466',
#   'tags': [''],
#   'label': ['Social group',
#    'Vacation',
#    'Fun',
#    'Tourism',
#    'Summer',
#    'Leisure',
#    'Beach',
#    'Event',
#    'Recreation',
#    'Team']},
#  '36408649332': {'url': 'https://live.staticflickr.com/4346/36408649332_b39fec4e34.jpg',
#   'latitude': '-8.378403',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134466',
#   'tags': [''],
#   'label': ['Horizon',
#    'Sea',
#    'Sky',
#    'Shore',
#    'Resort',
#    'Vacation',
#    'Tree',
#    'Evening',
#    'Beach',
#    'Ocean']},
#  '36403195132': {'url': 'https://live.staticflickr.com/4422/36403195132_a556ef280e.jpg',
#   'latitude': '-8.378403',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134466',
#   'tags': [''],
#   'label': ['Body of water',
#    'Beach',
#    'Shore',
#    'Sea',
#    'Sand',
#    'Coast',
#    'Ocean',
#    'Caribbean',
#    'Coastal and oceanic landforms',
#    'Azure']},
#  '27759728505': {'url': 'https://live.staticflickr.com/7567/27759728505_c80f49f416.jpg',
#   'latitude': '-8.282141',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.385348',
#   'tags': ['2015',
#    'baturbaguscottage',
#    'kintamani',
#    'kedisan',
#    'kampung',
#    'desa',
#    'village',
#    'banjar',
#    'temple',
#    'pura',
#    'celebration',
#    'ceremony',
#    'traditional',
#    'traditionaldress',
#    'tradition',
#    'asli',
#    'women',
#    'men',
#    'girls',
#    'kebaya',
#    'kamen',
#    'offerings',
#    'colourful',
#    'umbrella',
#    'baturbaguscottages',
#    'indra',
#    'fotograph',
#    ''],
#   'label': ['Sky',
#    'Beach',
#    'Palm tree',
#    'Caribbean',
#    'Tree',
#    'Vacation',
#    'Tropics',
#    'Cloud',
#    'Shore',
#    'Sand']},
#  '19705495745': {'url': 'https://live.staticflickr.com/529/19705495745_ca673cc318.jpg',
#   'latitude': '-8.145592',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '114.660162',
#   'tags': ['ludwig', ''],
#   'label': ['Hair',
#    'Face',
#    'Facial expression',
#    'Beach',
#    'Vacation',
#    'Skin',
#    'Sea',
#    'Sky',
#    'Smile',
#    'Beauty']},
#  '27340760417': {'url': 'https://live.staticflickr.com/976/27340760417_e86c9a9ef8.jpg',
#   'latitude': '-8.422898',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.278022',
#   'tags': [''],
#   'label': ['Coast',
#    'Beach',
#    'Shore',
#    'Kite sports',
#    'Sea',
#    'Windsports',
#    'Wind',
#    'Parachute',
#    'Coastal and oceanic landforms',
#    'Vacation']},
#  '31414737926': {'url': 'https://live.staticflickr.com/5687/31414737926_8e6e4f42b6.jpg',
#   'latitude': '-8.415939',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.315416',
#   'tags': ['travel', 'wander', 'tampaksiring', 'id', ''],
#   'label': ['Sky',
#    'Tree',
#    'Horizon',
#    'Palm tree',
#    'Sea',
#    'Beach',
#    'Arecales',
#    'Sunset',
#    'Woody plant',
#    'Morning']},
#  '37590380471': {'url': 'https://live.staticflickr.com/4469/37590380471_70623bdf54.jpg',
#   'latitude': '-8.432795',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.280577',
#   'tags': [''],
#   'label': ['Mode of transport',
#    'Transport',
#    'Vehicle',
#    'Travel',
#    'Tourism',
#    'Coast',
#    'Car',
#    'Ferry',
#    'Vacation',
#    'Beach']},
#  '45020086211': {'url': 'https://live.staticflickr.com/1917/45020086211_6f8b204d0e.jpg',
#   'latitude': '-8.315939',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.337141',
#   'tags': [''],
#   'label': ['Tree',
#    'Beach',
#    'Shore',
#    'Sea',
#    'Coast',
#    'Sand',
#    'Branch',
#    'Sky',
#    'Vacation',
#    'Woody plant']},
#  '40598074453': {'url': 'https://live.staticflickr.com/7905/40598074453_dfd4dd9887.jpg',
#   'latitude': '-8.448325',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.262833',
#   'tags': [''],
#   'label': ['Body of water',
#    'Sea',
#    'Ocean',
#    'Shore',
#    'Wave',
#    'Coast',
#    'Wind wave',
#    'Coastal and oceanic landforms',
#    'Beach',
#    'Water']},
#  '35559317913': {'url': 'https://live.staticflickr.com/4433/35559317913_12b577dd7a.jpg',
#   'latitude': '-8.378403',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134466',
#   'tags': [''],
#   'label': ['Body of water',
#    'Beach',
#    'Sea',
#    'Coast',
#    'Sky',
#    'Shore',
#    'Vacation',
#    'Ocean',
#    'Bay',
#    'Coastal and oceanic landforms']},
#  '36323209276': {'url': 'https://live.staticflickr.com/4427/36323209276_77559b8805.jpg',
#   'latitude': '-8.378403',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134466',
#   'tags': [''],
#   'label': ['Beach',
#    'Sky',
#    'Sea',
#    'Ocean',
#    'Vacation',
#    'Coast',
#    'Tourism',
#    'Sand',
#    'Horizon',
#    'Shore']},
#  '35631747523': {'url': 'https://live.staticflickr.com/4337/35631747523_5b33f51e9a.jpg',
#   'latitude': '-8.378403',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134466',
#   'tags': [''],
#   'label': ['Water',
#    'Water resources',
#    'Wave',
#    'Fun',
#    'Leisure',
#    'Beach',
#    'Vacation',
#    'Tourism',
#    'Sea',
#    'River']},
#  '23452048899': {'url': 'https://live.staticflickr.com/5680/23452048899_f50ec81899.jpg',
#   'latitude': '-8.433934',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.278780',
#   'tags': [''],
#   'label': ['Sky',
#    'Beach',
#    'Horizon',
#    'Sunset',
#    'Sea',
#    'Ocean',
#    'Sunrise',
#    'Shore',
#    'Coast',
#    'Evening']},
#  '34991229246': {'url': 'https://live.staticflickr.com/4270/34991229246_f26904f3f6.jpg',
#   'latitude': '-8.496409',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.250480',
#   'tags': [''],
#   'label': ['Beach',
#    'Vacation',
#    'Coast',
#    'Shore',
#    'Fun',
#    'Summer',
#    'Coastal and oceanic landforms',
#    'Tourism',
#    'Sea',
#    'Ocean']},
#  '24016609152': {'url': 'https://live.staticflickr.com/1604/24016609152_2ab80528eb.jpg',
#   'latitude': '-8.158206',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '114.662597',
#   'tags': [''],
#   'label': ['Body of water',
#    'Sky',
#    'Wave',
#    'Sea',
#    'Ocean',
#    'Wind wave',
#    'Water',
#    'Shore',
#    'Coast',
#    'Beach']},
#  '22190685216': {'url': 'https://live.staticflickr.com/5755/22190685216_7d71519498.jpg',
#   'latitude': '-8.246633',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.164498',
#   'tags': ['bedugul',
#    'loriculuspusillus',
#    'psitaccidae',
#    'yellowthroatedhangingparrot',
#    'birds',
#    'parrots',
#    ''],
#   'label': ['Sky',
#    'Horizon',
#    'Sea',
#    'Cloud',
#    'Ocean',
#    'Sunset',
#    'Beach',
#    'Shore',
#    'Evening',
#    'Morning']},
#  '44300237224': {'url': 'https://live.staticflickr.com/1962/44300237224_9dbde6f1a9.jpg',
#   'latitude': '-8.423287',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.310666',
#   'tags': ['gunungkawi', ''],
#   'label': ['Photograph',
#    'Vacation',
#    'Fun',
#    'Coast',
#    'Summer',
#    'Beach',
#    'Sea',
#    'Shore',
#    'Tourism',
#    'Ocean']},
#  '25470467817': {'url': 'https://live.staticflickr.com/4668/25470467817_fa4bb1e555.jpg',
#   'latitude': '-8.357842',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.300016',
#   'tags': [''],
#   'label': ['Vacation',
#    'Umbrella',
#    'Beach',
#    'Travel',
#    'Tourism',
#    'Summer',
#    'Sea',
#    'Ocean',
#    'Fun',
#    'Fashion accessory']},
#  '35970863000': {'url': 'https://live.staticflickr.com/4397/35970863000_ffc6bf3b4b.jpg',
#   'latitude': '-8.378403',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134466',
#   'tags': [''],
#   'label': ['Sea',
#    'Resort',
#    'Restaurant',
#    'Vacation',
#    'Tourism',
#    'Bay',
#    'Leisure',
#    'Coast',
#    'Shade',
#    'Beach']},
#  '45019282361': {'url': 'https://live.staticflickr.com/1956/45019282361_a95f9d5059.jpg',
#   'latitude': '-8.423287',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.310666',
#   'tags': ['gunungkawi', ''],
#   'label': ['Vacation',
#    'Coast',
#    'Sea',
#    'Tourism',
#    'Beach',
#    'Water',
#    'Fun',
#    'Summer',
#    'Ocean',
#    'Travel']},
#  '17923431140': {'url': 'https://live.staticflickr.com/7718/17923431140_d0a62765d5.jpg',
#   'latitude': '-8.351945',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.307222',
#   'tags': [''],
#   'label': ['Sky',
#    'Beach',
#    'Coast',
#    'Ocean',
#    'Sea',
#    'Cloud',
#    'Vacation',
#    'Tourism',
#    'Beauty',
#    'Shore']},
#  '23843859155': {'url': 'https://live.staticflickr.com/751/23843859155_46687e89d1.jpg',
#   'latitude': '-8.275489',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.166333',
#   'tags': ['puraulundanu', 'tempel', 'temple', 'baturiti', ''],
#   'label': ['People',
#    'Photograph',
#    'Vacation',
#    'Beach',
#    'Fun',
#    'Sea',
#    'Summer',
#    'Tourism',
#    'Coast',
#    'Ocean']},
#  '19599128463': {'url': 'https://live.staticflickr.com/357/19599128463_02fd63bb93.jpg',
#   'latitude': '-8.240181',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.379962',
#   'tags': ['2015',
#    'april',
#    'перезагрузка',
#    'перезагрузканабали',
#    'бали',
#    'mount',
#    'batur',
#    ''],
#   'label': ['Sun tanning',
#    'Beach',
#    'Sunlounger',
#    'Sand',
#    'Vacation',
#    'Umbrella',
#    'Sea',
#    'Outdoor furniture',
#    'Sky',
#    'Shade']},
#  '36013507050': {'url': 'https://live.staticflickr.com/4430/36013507050_93d33304d7.jpg',
#   'latitude': '-8.378403',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134466',
#   'tags': [''],
#   'label': ['People on beach',
#    'Sea',
#    'Beach',
#    'Ocean',
#    'Horizon',
#    'Shore',
#    'Coast',
#    'Sky',
#    'Evening',
#    'Fun']},
#  '31414796496': {'url': 'https://live.staticflickr.com/5816/31414796496_9ffaf71aab.jpg',
#   'latitude': '-8.272417',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.347522',
#   'tags': ['travel', 'wander', 'kintamani', 'id', ''],
#   'label': ['Body of water',
#    'Wave',
#    'Beach',
#    'Ocean',
#    'Sky',
#    'Sea',
#    'Wind wave',
#    'Coast',
#    'Water',
#    'Shore']},
# ...
#    'divesites',
#    'underwaterphotography',
#    'typeofphotography',
#    'biowreck',
#    'invertebrates',
#    'animals',
#    'seafans',
#    'pemuteran',
#    'gorgonians',
#    'octocorals',
#    ''],
#   'label': ['Sky',
#    'Cloud',
#    'Beach',
#    'Sea',
#    'Natural landscape',
#    'Sand',
#    'Horizon',
#    'Water',
#    'Photography',
#    'Tree']},
#  '23454213075': {'url': 'https://live.staticflickr.com/580/23454213075_7cc85d1ab1.jpg',
#   'latitude': '-8.246552',
#   'county': 'Karang Asem',
#   'longitude': '115.572738',
#   'tags': ['olympus', 'epl5', 'underwater', 'dive', 'diving', 'tulamben', ''],
#   'label': ['People',
#    'Child',
#    'Vacation',
#    'Fun',
#    'Summer',
#    'Beach',
#    'Smile',
#    'Travel',
#    'Adaptation',
#    'Tourism']},
#  '27179916960': {'url': 'https://live.staticflickr.com/7536/27179916960_eb3882e816.jpg',
#   'latitude': '-8.274914',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.166505',
#   'tags': ['danaubratan',
#    'pura',
#    'puraulundanuberatan',
#    'tempel',
#    'cloud',
#    'crop',
#    'temple',
#    'baturiti',
#    'id',
#    ''],
#   'label': ['Sky',
#    'Body of water',
#    'Beach',
#    'Horizon',
#    'Sea',
#    'Ocean',
#    'Cloud',
#    'Water',
#    'Sunset',
#    'Shore']},
#  '28910900982': {'url': 'https://live.staticflickr.com/8473/28910900982_091f1a6b27.jpg',
#   'latitude': '-8.414681',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.316300',
#   'tags': [''],
#   'label': ['People on beach',
#    'Beach',
#    'Coast',
#    'Vacation',
#    'Sea',
#    'Shore',
#    'Tourism',
#    'Ocean',
#    'Summer',
#    'Fun']},
#  '29604120572': {'url': 'https://live.staticflickr.com/8086/29604120572_69b4292679.jpg',
#   'latitude': '-8.378402',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134468',
#   'tags': [''],
#   'label': ['Sky',
#    'Beach',
#    'Sea',
#    'Water',
#    'Coast',
#    'Ocean',
#    'Cloud',
#    'Vacation',
#    'Reflection',
#    'Tourism']},
#  '30000291243': {'url': 'https://live.staticflickr.com/5752/30000291243_c52e926418.jpg',
#   'latitude': '-8.246552',
#   'county': 'Karang Asem',
#   'longitude': '115.572738',
#   'tags': [''],
#   'label': ['Sky',
#    'Horizon',
#    'Sunset',
#    'Sun',
#    'Sunrise',
#    'Sea',
#    'Ocean',
#    'Cloud',
#    'Beach',
#    'Evening']},
#  '31701632066': {'url': 'https://live.staticflickr.com/277/31701632066_95241052c2.jpg',
#   'latitude': '-8.279401',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.357369',
#   'tags': [''],
#   'label': ['Water transportation',
#    'Vacation',
#    'Tourism',
#    'Vehicle',
#    'Travel',
#    'Recreation',
#    'Sea',
#    'Leisure',
#    'Beach',
#    'Ocean']},
#  '16792879547': {'url': 'https://live.staticflickr.com/7585/16792879547_57e164793a.jpg',
#   'latitude': '-8.498523',
#   'county': 'Karang Asem',
#   'longitude': '115.611747',
#   'tags': ['karangasemsubdistrict', ''],
#   'label': ['Sea',
#    'Summer',
#    'Fun',
#    'Leg',
#    'Vacation',
#    'Swimwear',
#    'Photography',
#    'Beach',
#    'Ocean',
#    'Sportswear']},
#  '23631755259': {'url': 'https://live.staticflickr.com/5666/23631755259_f82303d05e.jpg',
#   'latitude': '-8.276650',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.166525',
#   'tags': ['dragon',
#    'lake',
#    'puraulundanu',
#    'temple',
#    'baturiti',
#    'water',
#    ''],
#   'label': ['Sky',
#    'Horizon',
#    'Sea',
#    'Sunset',
#    'Sunrise',
#    'Sun',
#    'Water',
#    'Ocean',
#    'Evening',
#    'Beach']},
#  '25343702192': {'url': 'https://live.staticflickr.com/1698/25343702192_00236ccc04.jpg',
#   'latitude': '-8.248474',
#   'county': 'Karang Asem',
#   'longitude': '115.574551',
#   'tags': ['diving', 'nurkowanie', 'tulamben', 'underwater', 'macro', ''],
#   'label': ['Sky',
#    'Sea',
#    'Horizon',
#    'Coast',
#    'Evening',
#    'Beach',
#    'Cloud',
#    'Sunset',
#    'Morning',
#    'Ocean']},
#  '38956544110': {'url': 'https://live.staticflickr.com/4799/38956544110_de822f1fd1.jpg',
#   'latitude': '-8.131653',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '114.655922',
#   'tags': ['photography',
#    'underwaterphotography',
#    'typeofphotography',
#    'biowreck',
#    'rhopalaeasp',
#    'tunicates',
#    'animals',
#    'pemuteran',
#    'invertebrates',
#    'divesites',
#    ''],
#   'label': ['Sky',
#    'Beach',
#    'Cloud',
#    'Horizon',
#    'Sea',
#    'Vacation',
#    'Sand',
#    'Shore',
#    'Coast',
#    'Summer']},
#  '24180586306': {'url': 'https://live.staticflickr.com/1689/24180586306_c870ce2fa1.jpg',
#   'latitude': '-8.404964',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.293280',
#   'tags': [''],
#   'label': ['Body of water',
#    'Beach',
#    'Wave',
#    'Ocean',
#    'Sea',
#    'Sky',
#    'Shore',
#    'Nature',
#    'Photograph',
#    'Horizon']},
#  '24709917370': {'url': 'https://live.staticflickr.com/1612/24709917370_15c59bb233.jpg',
#   'latitude': '-8.083753',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.133950',
#   'tags': ['pura', 'beji', ''],
#   'label': ['Tree',
#    'Beach',
#    'Sand',
#    'Shore',
#    'Sky',
#    'Coast',
#    'Woody plant',
#    'Vacation',
#    'Sea',
#    'Ocean']},
#  '27356933072': {'url': 'https://live.staticflickr.com/7383/27356933072_72234c039f.jpg',
#   'latitude': '-8.275264',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.166427',
#   'tags': ['danaubratan',
#    'pura',
#    'puraulundanuberatan',
#    'tempel',
#    'sooc',
#    'temple',
#    'baturiti',
#    'id',
#    ''],
#   'label': ['Vacation',
#    'Sun tanning',
#    'Fun',
#    'Summer',
#    'Leisure',
#    'Sky',
#    'Tourism',
#    'Water',
#    'Beach',
#    'Sunlight']},
#  '36691022400': {'url': 'https://live.staticflickr.com/4360/36691022400_80f576dbba.jpg',
#   'latitude': '-8.358544',
#   'county': 'Karang Asem',
#   'longitude': '115.697482',
#   'tags': ['mer',
#    'océan',
#    'ocean',
#    'waves',
#    'vagues',
#    'olas',
#    'asia',
#    'sea',
#    'mar',
#    'océans',
#    'blue',
#    'bleus',
#    'azul',
#    'azzurro',
#    'pecheur',
#    ''],
#   'label': ['Body of water',
#    'Water',
#    'Sea',
#    'Sky',
#    'Ocean',
#    'Coast',
#    'Water resources',
#    'Beach',
#    'Coastal and oceanic landforms',
#    'Shore']},
#  '27179917140': {'url': 'https://live.staticflickr.com/7459/27179917140_0364092bdf.jpg',
#   'latitude': '-8.275612',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.166155',
#   'tags': ['danaubratan',
#    'pura',
#    'puraulundanuberatan',
#    'tempel',
#    'sooc',
#    'temple',
#    'baturiti',
#    'id',
#    ''],
#   'label': ['White',
#    'Beach',
#    'Water',
#    'Black',
#    'Photograph',
#    'Sky',
#    'Sea',
#    'Black-and-white',
#    'Monochrome photography',
#    'Sand']},
#  '46811914325': {'url': 'https://live.staticflickr.com/65535/46811914325_70c1d102c5.jpg',
#   'latitude': '-8.496353',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.253455',
#   'tags': ['asia', 'hindu', 'templeparade', 'ubud', ''],
#   'label': ['Sky',
#    'Body of water',
#    'Horizon',
#    'Sea',
#    'Shore',
#    'Cloud',
#    'Ocean',
#    'Atmospheric phenomenon',
#    'Coast',
#    'Beach']},
#  '23910228102': {'url': 'https://live.staticflickr.com/1648/23910228102_fba40e0d57.jpg',
#   'latitude': '-8.145342',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.031108',
#   'tags': ['boat',
#    'dolphin',
#    'dolphinwatching',
#    'lovina',
#    'ocean',
#    'sea',
#    'kecamatanbuleleng',
#    'water',
#    ''],
#   'label': ['Sky',
#    'Tree',
#    'Blue',
#    'Beach',
#    'Ocean',
#    'Tropics',
#    'Sea',
#    'Plant',
#    'Woody plant',
#    'Branch']},
#  '39445208075': {'url': 'https://live.staticflickr.com/4719/39445208075_a18653a6e7.jpg',
#   'latitude': '-8.195928',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '114.911687',
#   'tags': [''],
#   'label': ['Water',
#    'Flood',
#    'Event',
#    'Beach',
#    'Coast',
#    'Vacation',
#    'Tourism']},
#  '38956543590': {'url': 'https://live.staticflickr.com/4800/38956543590_8b56ed974a.jpg',
#   'latitude': '-8.131653',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '114.655922',
#   'tags': ['ophiothrixsp',
#    'photography',
#    'typeofphotography',
#    'brittleandbasketstars',
#    'biowreck',
#    'underwaterphotography',
#    'animals',
#    'echinoderms',
#    'pemuteran',
#    'invertebrates',
#    'divesites',
#    ''],
#   'label': ['Sky',
#    'Horizon',
#    'Sea',
#    'Beach',
#    'Cloud',
#    'Photography',
#    'Sand',
#    'Ocean',
#    'Shore',
#    'Coast']},
#  '23312339191': {'url': 'https://live.staticflickr.com/706/23312339191_5f5118ddeb.jpg',
#   'latitude': '-8.246552',
#   'county': 'Karang Asem',
#   'longitude': '115.572738',
#   'tags': ['olympus', 'epl5', 'underwater', 'dive', 'diving', 'tulamben', ''],
#   'label': ['Body of water',
#    'Beach',
#    'Sea',
#    'Sky',
#    'Water',
#    'Ocean',
#    'Blue',
#    'Coast',
#    'Coastal and oceanic landforms',
#    'Vacation']},
#  '24911626001': {'url': 'https://live.staticflickr.com/1513/24911626001_196a1a0b10.jpg',
#   'latitude': '-8.412612',
#   'county': 'Karang Asem',
#   'longitude': '115.586586',
#   'tags': ['tirta', 'gangga', ''],
#   'label': ['Sky',
#    'Umbrella',
#    'Evening',
#    'Vacation',
#    'Sea',
#    'Beach',
#    'Cloud',
#    'Tourism',
#    'Summer',
#    'Horizon']},
#  '26930933441': {'url': 'https://live.staticflickr.com/7195/26930933441_f7fa6122ca.jpg',
#   'latitude': '-8.282141',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.385348',
#   'tags': ['2015',
#    'kintamani',
#    'kedisan',
#    'kampung',
#    'village',
#    'desa',
#    'danaubatur',
#    'lakebatur',
#    'mountbatur',
#    'gunungbatur',
#    'mountain',
#    'lake',
#    'baturbaguscottage',
#    'pura',
#    'temple',
#    'hindu',
#    'agama',
#    'ceremony',
#    'offerings',
#    'afternoon',
#    'men',
#    'colour',
#    'colourful',
#    'white',
#    'old',
#    'decoration',
#    'decorated',
#    'kamen',
#    'udeng',
#    ''],
#   'label': ['Body of water',
#    'Beach',
#    'Coast',
#    'Sea',
#    'Coastal and oceanic landforms',
#    'Shore',
#    'Promontory',
#    'Sky',
#    'Ocean',
#    'Vacation']},
#  '27661772322': {'url': 'https://live.staticflickr.com/7086/27661772322_d19aa599b6.jpg',
#   'latitude': '-8.282141',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.385348',
#   'tags': ['2015',
#    'baturbaguscottage',
#    'kintamani',
#    'kedisan',
#    'kampung',
#    'desa',
#    'village',
#    'banjar',
#    'young',
#    'man',
#    'face',
#    'traditional',
#    'traditionaldress',
#    'udeng',
#    'happy',
#    'smile',
#    'smiling',
#    'baturbaguscottages',
#    'indra',
#    'fotograph',
#    ''],
#   'label': ['Body of water',
#    'Coast',
#    'Sea',
#    'Nature',
#    'Shore',
#    'Natural landscape',
#    'Beach',
#    'Coastal and oceanic landforms',
#    'Headland',
#    'Ocean']},
#  '45992625844': {'url': 'https://live.staticflickr.com/4888/45992625844_f9a1fbb123.jpg',
#   'latitude': '-8.391491',
#   'county': 'Tabanan Kabupaten',
#   'longitude': '115.125871',
#   'tags': ['asia', ''],
#   'label': ['Beach',
#    'Sky',
#    'Tourism',
#    'Sand',
#    'Vacation',
#    'Summer',
#    'Leisure',
#    'Team',
#    'Vehicle',
#    'Photography']},
#  '28612856847': {'url': 'https://live.staticflickr.com/1809/28612856847_1555aaaa1b.jpg',
#   'latitude': '-8.150367',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '114.609680',
#   'tags': ['yoga',
#    'yogaretreat',
#    'sumberkimahill',
#    'view',
#    'panorama',
#    'holiday',
#    'villa',
#    'rent',
#    ''],
#   'label': ['Sky',
#    'Shore',
#    'Beach',
#    'Sea',
#    'Water',
#    'Horizon',
#    'Ocean',
#    'Calm',
#    'Cloud',
#    'Coast']},
#  '40304007972': {'url': 'https://live.staticflickr.com/4721/40304007972_472f4b2122.jpg',
#   'latitude': '-8.195928',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '114.911687',
#   'tags': [''],
#   'label': ['People on beach',
#    'Vacation',
#    'Fun',
#    'Beach',
#    'Summer',
#    'Smile',
#    'Muscle',
#    'Cool',
#    'Happy',
#    'Photography']},
#  '40635307224': {'url': 'https://live.staticflickr.com/876/40635307224_c1b2dd55be.jpg',
#   'latitude': '-8.336431',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.186844',
#   'tags': ['baturiti', ''],
#   'label': ['Beach',
#    'Body of water',
#    'Sea',
#    'Coast',
#    'Ocean',
#    'Shore',
#    'Sand',
#    'Sky',
#    'Vacation',
#    'Coastal and oceanic landforms']},
#  '24374230744': {'url': 'https://live.staticflickr.com/1513/24374230744_4c8c028219.jpg',
#   'latitude': '-8.412267',
#   'county': 'Karang Asem',
#   'longitude': '115.586983',
#   'tags': ['tirta', 'gangga', ''],
#   'label': ['Beach',
#    'Water',
#    'Tourism',
#    'Fun',
#    'Coast',
#    'Shore',
#    'Vacation',
#    'Leisure',
#    'Sea',
#    'Summer']},
#  '21863619306': {'url': 'https://live.staticflickr.com/5811/21863619306_7de9224094.jpg',
#   'latitude': '-8.370023',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.130939',
#   'tags': [''],
#   'label': ['Fun',
#    'Vacation',
#    'Summer',
#    'Sea',
#    'Beach',
#    'Water',
#    'Child',
#    'Happy',
#    'Swimwear',
#    'Ocean']},
#  '24912184931': {'url': 'https://live.staticflickr.com/1502/24912184931_276ae3c3e0.jpg',
#   'latitude': '-8.083606',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.134094',
#   'tags': ['pura', 'beji', ''],
#   'label': ['Beach',
#    'Sea',
#    'Vacation',
#    'Shore',
#    'Sand',
#    'Landscape',
#    'Coast',
#    'Ocean',
#    'Tourism',
#    'Horizon']},
#  '20395959086': {'url': 'https://live.staticflickr.com/558/20395959086_feaa6a01f8.jpg',
#   'latitude': '-8.347062',
#   'county': 'Karang Asem',
#   'longitude': '115.507752',
#   'tags': [''],
#   'label': ['Body of water',
#    'Sky',
#    'Horizon',
#    'Sea',
#    'Shore',
#    'Coast',
#    'Ocean',
#    'Beach',
#    'Water',
#    'Evening']},
#  '41598191691': {'url': 'https://live.staticflickr.com/785/41598191691_239844bf83.jpg',
#   'latitude': '-8.299745',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.177611',
#   'tags': ['baturiti', ''],
#   'label': ['Outdoor furniture',
#    'Shore',
#    'Sunlounger',
#    'Turquoise',
#    'Beach',
#    'Sea',
#    'Coast',
#    'Vacation',
#    'Furniture',
#    'Tree']},
#  '32289855303': {'url': 'https://live.staticflickr.com/2918/32289855303_83330b998a.jpg',
#   'latitude': '-8.280324',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.385537',
#   'tags': [''],
#   'label': ['Tourism',
#    'Vacation',
#    'Beach',
#    'Vehicle',
#    'Fun',
#    'Coast',
#    'Summer',
#    'Travel',
#    'Leisure',
#    'Sea']},
#  '35575120346': {'url': 'https://live.staticflickr.com/4228/35575120346_e1740fc016.jpg',
#   'latitude': '-8.239657',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.069727',
#   'tags': ['indo',
#    'island',
#    'travel',
#    'michel',
#    'michél',
#    'pretzsch',
#    'diamir',
#    'erlebnisreisen',
#    'sony',
#    'alpha',
#    '6000',
#    'voyage',
#    'gods',
#    'archipelago',
#    'nature',
#    'culture',
#    'banana',
#    'green',
#    'leaf',
#    'plant',
#    'plantation',
#    ''],
#   'label': ['Sky',
#    'Sea',
#    'Horizon',
#    'Ocean',
#    'Water',
#    'Calm',
#    'Beach',
#    'Coast',
#    'Shore',
#    'Vacation']},
#  '24978604886': {'url': 'https://live.staticflickr.com/1560/24978604886_4844317e87.jpg',
#   'latitude': '-8.412553',
#   'county': 'Karang Asem',
#   'longitude': '115.586538',
#   'tags': ['tirta', 'gangga', ''],
#   'label': ['Sky',
#    'Horizon',
#    'Beach',
#    'Sea',
#    'Ocean',
#    'Cloud',
#    'Evening',
#    'Shore',
#    'Sunset',
#    'Wave']},
#  '23689083025': {'url': 'https://live.staticflickr.com/726/23689083025_ff41915a47.jpg',
#   'latitude': '-8.210502',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '114.973994',
#   'tags': ['brahmaviharaarama', ''],
#   'label': ['Sky',
#    'Horizon',
#    'Cloud',
#    'Ocean',
#    'Sunset',
#    'Water',
#    'Sea',
#    'Beach',
#    'Evening',
#    'Morning']},
#  '33991858440': {'url': 'https://live.staticflickr.com/2888/33991858440_393db1db79.jpg',
#   'latitude': '-8.432792',
#   'county': 'Gianyar Kabupaten',
#   'longitude': '115.280447',
#   'tags': ['file:md5sum=f6ffe6a5c1339e2841f8eaa5c5f5a6ab',
#    'file:sha1sig=57c8116eabda1237834a8b5951199c2f40fd9883',
#    ''],
#   'label': ['Body of water',
#    'Coast',
#    'Nature',
#    'Sea',
#    'Beach',
#    'Shore',
#    'Water',
#    'Sky',
#    'Natural landscape',
#    'Water resources']},
#  '34643321354': {'url': 'https://live.staticflickr.com/4279/34643321354_36eac555b2.jpg',
#   'latitude': '-8.236795',
#   'county': 'Buleleng Kabupaten',
#   'longitude': '115.378994',
#   'tags': ['mountbatur',
#    'sunrise',
#    'gunungbatur',
#    'shilouette',
#    'kintamani',
#    'ctheisinger',
#    'caldera',
#    'bench',
#    'summit',
#    'volcano',
#    'clouds',
#    'id',
#    ''],
#   'label': ['Sky',
#    'Vacation',
#    'Sea',
#    'Tourism',
#    'Ocean',
#    'Cloud',
#    'Fun',
#    'Summer',
#    'Travel',
#    'Beach']}}
